# %%
# Load modules
# %pylab inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn import datasets, metrics, tree, cross_validation

# %%
# Load in data and create training and test sets. dropping all na columns, for kicks.
l_train = pd.read_csv('../data/cars/lemon_training.csv')
l_test = pd.read_csv('../data/cars/lemon_test.csv')

# %%
l_test.head(5)
# Out:
#    RefId  PurchDate Auction  VehYear  VehicleAge   Make         Model Trim  \
# 0      3  12/7/2009   ADESA     2005           4  DODGE    STRATUS V6  SXT
# 1      4  12/7/2009   ADESA     2004           5  DODGE          NEON  SXT
# 2      8  12/7/2009   ADESA     2005           4   FORD        TAURUS   SE
# 3      9  12/7/2009   ADESA     2007           2    KIA       SPECTRA   EX
# 4     10  12/7/2009   ADESA     2007           2   FORD  FIVE HUNDRED  SEL
#
#            SubModel   Color Transmission  WheelTypeID WheelType  VehOdo  \
# 0  4D SEDAN SXT FFV  MAROON         AUTO            2    Covers   73807
# 1          4D SEDAN  SILVER         AUTO            1     Alloy   65617
# 2       4D SEDAN SE   WHITE         AUTO            2    Covers   65805
# 3       4D SEDAN EX   BLACK         AUTO            2    Covers   49921
# 4      4D SEDAN SEL     RED         AUTO            1     Alloy   84872
#
#    Nationality     Size TopThreeAmericanName  \
# 0     AMERICAN   MEDIUM             CHRYSLER
# 1     AMERICAN  COMPACT             CHRYSLER
# 2     AMERICAN   MEDIUM                 FORD
# 3  OTHER ASIAN   MEDIUM                OTHER
# 4     AMERICAN    LARGE                 FORD
#
#    MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# 0                               3202                             4760
# 1                               1893                             2675
# 2                               3313                             4342
# 3                               6196                             7274
# 4                               7845                             9752
#
#    MMRAcquisitionRetailAveragePrice
# 0                              6943 ...
# 1                              4658 ...
# 2                              6667 ...
# 3                              9687 ...
# 4                             11734 ...
#
# [5 rows x 33 columns]

# %%
l_train = l_train.dropna(axis=1)
l_test = l_test.dropna(axis=1)

# %%
l_test.head(5)
# Out:
#    RefId  PurchDate Auction  VehYear  VehicleAge   Make         Model  VehOdo  \
# 0      3  12/7/2009   ADESA     2005           4  DODGE    STRATUS V6   73807
# 1      4  12/7/2009   ADESA     2004           5  DODGE          NEON   65617
# 2      8  12/7/2009   ADESA     2005           4   FORD        TAURUS   65805
# 3      9  12/7/2009   ADESA     2007           2    KIA       SPECTRA   49921
# 4     10  12/7/2009   ADESA     2007           2   FORD  FIVE HUNDRED   84872
#
#    BYRNO  VNZIP1 VNST  VehBCost  IsOnlineSale  WarrantyCost
# 0  19638   33619   FL      4900             0          1389
# 1  19638   33619   FL      4100             0           630
# 2  19638   33619   FL      4500             0           825
# 3  21973   33619   FL      5600             0           482
# 4  21973   33619   FL      7700             0          1633
#
# [5 rows x 14 columns]

# %%
# Generating a list of continuous data features from the describe dataframe. 
# Then, removing the two non-features (RefId is an index, IsBadBuy is the prediction value)
features = list(l_train.describe().columns)
features.remove('RefId')
features.remove('IsBadBuy')

# %%
features
# Out:
# ['VehYear',
#  'VehicleAge',
#  'VehOdo',
#  'BYRNO',
#  'VNZIP1',
#  'VehBCost',
#  'IsOnlineSale',
#  'WarrantyCost']

# %%
# Creating the actual training and test sets. Yours should cross validate on the training data.
train_X = l_train[features].values
train_y = l_train.IsBadBuy.values
test_X = l_test[features].values

# %%
train_y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Create a classifier and prediction.
clf = tree.DecisionTreeClassifier(max_depth=5,  min_samples_leaf=3).fit(train_X, train_y)
clf.score(train_X, train_y)
y_pred = clf.predict(test_X)

# %%
# Create a submission
submission = pd.DataFrame({ 'RefId' : l_test.RefId, 'prediction' : y_pred })
submission.to_csv('submission_jhave.csv')

# %%
submission
# Out:
#     RefId  prediction
# 0       3           0
# 1       4           0
# 2       8           0
# 3       9           0
# 4      10           0
# 5      11           0
# 6      12           0
# 7      14           0
# 8      19           0
# 9      21           0
# 10     23           0
# 11     25           0
# 12     29           0
# 13     32           0
# 14     33           0
# 15     37           0
# 16     40           0
# 17     41           0
# 18     45           0
# 19     46           0
# 20     48           0
# 21     49           0
# 22     51           0
# 23     63           0
# 24     64           0
# 25     65           0
# 26     69           0
# 27     70           0
# 28     71           0
# 29     78           0
# 30     81           0
# 31     86           0
# 32     90           0
# 33     95           0
# 34     96           0
# 35     97           0
# 36    100           0
# 37    106           0
# 38    110           0
# 39    113           0
# 40    115           0
# 41    116           0
# 42    117           0
# 43    120           0
# 44    122           0
# 45    123           0
# 46    124           0
# 47    128           0
# 48    130           0
# 49    131           0
# 50    132           0
# 51    134           0
# 52    135           0
# 53    147           0
# 54    149           0
# 55    150           0
# 56    152           0
# 57    156           0
# 58    158           0
# 59    164           0
#       ...         ...
#
# [21895 rows x 2 columns]
